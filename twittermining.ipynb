# %%
#from https://dev.mention.com/current/src/guides/twitter.html 
# !pip install rauth
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rauth
#   Downloading rauth-0.7.3.tar.gz (16 kB)
# Requirement already satisfied: requests>=1.2.3 in /usr/local/lib/python3.7/dist-packages (from rauth) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.3->rauth) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.3->rauth) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.3->rauth) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.3->rauth) (3.0.4)
# Building wheels for collected packages: rauth
#   Building wheel for rauth (setup.py) ... done
#   Created wheel for rauth: filename=rauth-0.7.3-py3-none-any.whl size=16081 sha256=10bc09380d7820169e4c729cbd0ee86db72f98d061e3c745590cddde83374f66
#   Stored in directory: /root/.cache/pip/wheels/72/7a/33/ad03f8d424e1ca6e8e53da0cea1849596ca9b7ab7ecf0b3c5d
# Successfully built rauth
# Installing collected packages: rauth
# Successfully installed rauth-0.7.3

# %%
#run keys
# %run ./keys.ipynb

# %% [markdown]
# **Retrieving and Storing Metadata from a Tweet using URL as input**

# %% [markdown]
# This hopefully can be used to build the graphic later.

# %%
from rauth import OAuth1Service
import json
import pandas as pd

# Instantiate a client
twitter_client = OAuth1Service(name='twitter',
                              consumer_key=consumer_key,
                              consumer_secret=consumer_secret,
                              base_url='https://api.twitter.com/1.1/')

twitter_session = twitter_client.get_session((access_token, access_token_secret))

# Request the metadata of a tweet
def get_metadata(url1):
    id = url1.split('/')[-1]
    
    #tweet URL (api) and id
    ID = [id]
    URL = 'https://api.twitter.com/1.1/statuses/lookup.json'
    
    #get request
    r = twitter_session.get(URL,
                            params={'id': ','.join(ID)})

    #retrieve metadata in JSON format
    h = r.json()
    #JSON dictionary of initial tweet
    dict = h[0]
    
    print(json.dumps(h, indent=2))

    #data we want: Tweet URL, Retweets, Likes, Author handle, Author profile URL, Author bio, Followers
    metadata = {}
    #expanded url
    meta_url = dict["entities"]["urls"][0]["expanded_url"]
    #retweets
    retweets = dict["retweet_count"]
    #likes
    likes = dict["favorite_count"]
    #author info
    author_dict = dict["user"]
    name = author_dict["name"]
    handle = author_dict["screen_name"]
    bio = author_dict["description"]
    #followers - write rounding formula with mod later (for K or M, or B?)
    followers = author_dict["followers_count"]

    #store in dictionary
    metadata = {"URL": [meta_url], "Retweets": [retweets], "Likes": [likes], "Author name": [name], "Author handle": [handle], "Author bio": [bio], "Author followers": [followers]}
    print(metadata)
    
    return metadata
    
def main():
    #create dataframe of metadata for organization
    #column_names = ["Tweet URL", "Retweets", "Likes", "Author name", "Author handle", "Author bio", "Author followers"]
    #twitter_data = pd.DataFrame(columns = column_names)
    twitter_data = pd.DataFrame()

    #input link
    tweet = input("tweet link: ")
    
    #store metadata in dataframe
    meta_df = pd.DataFrame(get_metadata(tweet))
    
    twitter_data = pd.concat([meta_df, twitter_data], ignore_index=True)

    # print(twitter_data)
    
if __name__ == "__main__":
    main()
    
# switch to class/object-oriented, rather than dataframe?
# Out:
# tweet link:  https://twitter.com/MnetMcountdown/status/1537363077909614593
# [
#   {
#     "created_at": "Thu Jun 16 09:14:55 +0000 2022",
#     "id": 1537363077909614593,
#     "id_str": "1537363077909614593",
#     "text": "\uc6b0\ub9ac\uc758 \uc790\ub791 \uc138\uacc4\uc758 \uc790\ub791 \uc6b0\uc8fc\uc758 \uc790\ub791\ud83e\udd79\n\ud568\uaed8\ub77c\uba74 \uc0ac\ub9c9\ub3c4 \ubc14\ub2e4\uac00 \ub418\ub294 \uae30\uc801\ud83c\udf81\n\uae34 \ub9d0 \ud558\uc9c0 \uc54a\uaca0\uc2b5\ub2c8\ub2e4...\n\uc544\ud3ec\ubc29\ud3ec \ubc29\ubb34\ud589\uc54c \uc544\ubb34\ud589\uc54c \ud83d\udc9c\ubcf4\ub77c\ud574\ud83d\udc9c #\ubc29\ud0c4\uc18c\ub144\ub2e8 #BTS #YetToCome #\uc5e0\uce74\ubcf8\ubc29\uc0ac\uc218\ud544\uc218 \u203c\ufe0f https://t.co/JBmyw9lcKE",
#     "truncated": false,
#     "entities": {
#       "hashtags": [
#         {
#           "text": "\ubc29\ud0c4\uc18c\ub144\ub2e8",
#           "indices": [
#             79,
#             85
#           ]
#         },
#         {
#           "text": "BTS",
#           "indices": [
#             86,
#             90
#           ]
#         },
#         {
#           "text": "YetToCome",
#           "indices": [
#             91,
#             101
#           ]
#         },
#         {
#           "text": "\uc5e0\uce74\ubcf8\ubc29\uc0ac\uc218\ud544\uc218",
#           "indices": [
#             102,
#             111
#           ]
#         }
#       ],
#       "symbols": [],
#       "user_mentions": [],
#       "urls": [],
#       "media": [
#         {
#           "id": 1537363064320049152,
#           "id_str": "1537363064320049152",
#           "indices": [
#             115,
#             138
#           ],
#           "media_url": "http://pbs.twimg.com/media/FVXPj8uaQAAvTn6.jpg",
#           "media_url_https": "https://pbs.twimg.com/media/FVXPj8uaQAAvTn6.jpg",
#           "url": "https://t.co/JBmyw9lcKE",
#           "display_url": "pic.twitter.com/JBmyw9lcKE",
#           "expanded_url": "https://twitter.com/MnetMcountdown/status/1537363077909614593/photo/1",
#           "type": "photo",
#           "sizes": {
#             "thumb": {
#               "w": 150,
#               "h": 150,
#               "resize": "crop"
#             },
#             "medium": {
#               "w": 1200,
#               "h": 875,
#               "resize": "fit"
#             },
#             "small": {
#               "w": 680,
#               "h": 496,
#               "resize": "fit"
#             },
#             "large": {
#               "w": 2048,
#               "h": 1494,
#               "resize": "fit"
#             }
#           }
#         }
#       ]
#     },
#     "extended_entities": {
#       "media": [
#         {
#           "id": 1537363064320049152,
#           "id_str": "1537363064320049152",
#           "indices": [
#             115,
#             138
#           ],
#           "media_url": "http://pbs.twimg.com/media/FVXPj8uaQAAvTn6.jpg",
#           "media_url_https": "https://pbs.twimg.com/media/FVXPj8uaQAAvTn6.jpg",
#           "url": "https://t.co/JBmyw9lcKE",
#           "display_url": "pic.twitter.com/JBmyw9lcKE",
#           "expanded_url": "https://twitter.com/MnetMcountdown/status/1537363077909614593/photo/1",
#           "type": "photo",
#           "sizes": {
#             "thumb": {
#               "w": 150,
#               "h": 150,
#               "resize": "crop"
#             },
#             "medium": {
#               "w": 1200,
#               "h": 875,
#               "resize": "fit"
#             },
#             "small": {
#               "w": 680,
#               "h": 496,
#               "resize": "fit"
#             },
#             "large": {
#               "w": 2048,
#               "h": 1494,
#               "resize": "fit"
#             }
#           }
#         },
#         {
#           "id": 1537363064336842752,
#           "id_str": "1537363064336842752",
#           "indices": [
#             115,
#             138
#           ],
#           "media_url": "http://pbs.twimg.com/media/FVXPj8yagAA5o5P.jpg",
#           "media_url_https": "https://pbs.twimg.com/media/FVXPj8yagAA5o5P.jpg",
#           "url": "https://t.co/JBmyw9lcKE",
#           "display_url": "pic.twitter.com/JBmyw9lcKE",
#           "expanded_url": "https://twitter.com/MnetMcountdown/status/1537363077909614593/photo/1",
#           "type": "photo",
#           "sizes": {
#             "thumb": {
#               "w": 150,
#               "h": 150,
#               "resize": "crop"
#             },
#             "small": {
#               "w": 680,
#               "h": 510,
#               "resize": "fit"
#             },
#             "large": {
#               "w": 2048,
#               "h": 1536,
#               "resize": "fit"
#             },
#             "medium": {
#               "w": 1200,
#               "h": 900,
#               "resize": "fit"
#             }
#           }
#         }
#       ]
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#       "id": 128479879,
#       "id_str": "128479879",
#       "name": "M COUNTDOWN",
#       "screen_name": "MnetMcountdown",
#       "location": "Seoul, South Korea",
#       "description": "World No.1 Kpop Chart Show M COUNTDOWN \nEvery Thur 6PM(KST) Mnet Live on Air",
#       "url": "https://t.co/gKJd4srK5X",
#       "entities": {
#         "url": {
#           "urls": [
#             {
#               "url": "https://t.co/gKJd4srK5X",
#               "expanded_url": "https://mcountdown.genie.co.kr/",
#               "display_url": "mcountdown.genie.co.kr",
#               "indices": [
#                 0,
#                 23
#               ]
#             }
#           ]
#         },
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 3825656,
#       "friends_count": 0,
#       "listed_count": 4663,
#       "created_at": "Thu Apr 01 07:11:48 +0000 2010",
#       "favourites_count": 10,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": true,
#       "statuses_count": 11469,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "ABB8C2",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1361485890388783105/8JPHSXGO_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1361485890388783105/8JPHSXGO_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/128479879/1649328771",
#       "profile_link_color": "F5ABB5",
#       "profile_sidebar_border_color": "EEEEEE",
#       "profile_sidebar_fill_color": "EFEFEF",
#       "profile_text_color": "333333",
#       "profile_use_background_image": false,
#       "has_extended_profile": false,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none",
#       "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 272520,
#     "favorite_count": 774974,
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": true,
#     "lang": "ko"
#   }
# ]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [1], in <cell line: 76>()
#      74     # print(twitter_data)
#      76 if __name__ == "__main__":
# ---> 77     main()
#
# Input In [1], in main()
#      67 tweet = input("tweet link: ")
#      69 #store metadata in dataframe
# ---> 70 meta_df = pd.DataFrame(get_metadata(tweet))
#      72 twitter_data = pd.concat([meta_df, twitter_data], ignore_index=True)
#
# Input In [1], in get_metadata(url1)
#      39 metadata = {}
#      40 #expanded url
# ---> 41 meta_url = dict["entities"]["urls"][0]["expanded_url"]
#      42 #retweets
#      43 retweets = dict["retweet_count"]
#
# IndexError: list index out of range
